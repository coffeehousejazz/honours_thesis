# %%
# %pip install pymongo
# %pip install pandas
# %pip install geopy
# %pip install folium
# %pip install seaborn
# %pip install matplotlib
# Out:
# Requirement already satisfied: pymongo in /usr/local/lib/python3.10/site-packages (4.3.3)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /usr/local/lib/python3.10/site-packages (from pymongo) (2.2.1)
#
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: python3.10 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# ^C
# Traceback (most recent call last):
#   File "/usr/local/Cellar/python@3.10/3.10.8/Frameworks/Python.framework/Versions/3.10/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/local/Cellar/python@3.10/3.10.8/Frameworks/Python.framework/Versions/3.10/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/usr/local/lib/python3.10/site-packages/pip/__main__.py", line 29, in <module>
#     from pip._internal.cli.main import main as _main
#   File "/usr/local/lib/python3.10/site-packages/pip/_internal/cli/main.py", line 9, in <module>
#     from pip._internal.cli.autocompletion import autocomplete
#   File "/usr/local/lib/python3.10/site-packages/pip/_internal/cli/autocompletion.py", line 10, in <module>
#     from pip._internal.cli.main_parser import create_main_parser
#   File "/usr/local/lib/python3.10/site-packages/pip/_internal/cli/main_parser.py", line 9, in <module>
#     from pip._internal.build_env import get_runnable_pip
#   File "/usr/local/lib/python3.10/site-packages/pip/_internal/build_env.py", line 20, in <module>
#     from pip._internal.cli.spinners import open_spinner
#   File "/usr/local/lib/python3.10/site-packages/pip/_internal/cli/spinners.py", line 9, in <module>
#     from pip._internal.utils.logging import get_indentation
#   File "/usr/local/lib/python3.10/site-packages/pip/_internal/utils/logging.py", line 13, in <module>
#     from pip._vendor.rich.console import (
#   File "/usr/local/lib/python3.10/site-packages/pip/_vendor/rich/console.py", line 120, in <module>
#     class ConsoleOptions:
#   File "/usr/local/Cellar/python@3.10/3.10.8/Frameworks/Python.framework/Versions/3.10/lib/python3.10/dataclasses.py", line 1185, in dataclass
#     return wrap(cls)
#   File "/usr/local/Cellar/python@3.10/3.10.8/Frameworks/Python.framework/Versions/3.10/lib/python3.10/dataclasses.py", line 1176, in wrap
#     return _process_class(cls, init, repr, eq, order, unsafe_hash,
#   File "/usr/local/Cellar/python@3.10/3.10.8/Frameworks/Python.framework/Versions/3.10/lib/python3.10/dataclasses.py", line 1054, in _process_class
#     _cmp_fn('__eq__', '==',
#   File "/usr/local/Cellar/python@3.10/3.10.8/Frameworks/Python.framework/Versions/3.10/lib/python3.10/dataclasses.py", line 630, in _cmp_fn
#     return _create_fn(name,
#   File "/usr/local/Cellar/python@3.10/3.10.8/Frameworks/Python.framework/Versions/3.10/lib/python3.10/dataclasses.py", line 434, in _create_fn
#     exec(txt, globals, ns)
#   File "<string>", line 1, in <module>
# KeyboardInterrupt
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: geopy in /usr/local/lib/python3.10/site-packages (2.3.0)
# Requirement already satisfied: geographiclib<3,>=1.52 in /usr/local/lib/python3.10/site-packages (from geopy) (2.0)
#
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: python3.10 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: folium in /usr/local/lib/python3.10/site-packages (0.14.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/site-packages (from folium) (1.24.2)
# Requirement already satisfied: branca>=0.6.0 in /usr/local/lib/python3.10/site-packages (from folium) (0.6.0)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/lib/python3.10/site-packages (from folium) (3.1.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/site-packages (from folium) (2.28.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/site-packages (from jinja2>=2.9->folium) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/site-packages (from requests->folium) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in /usr/local/lib/python3.10/site-packages (from requests->folium) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/site-packages (from requests->folium) (2022.9.24)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/site-packages (from requests->folium) (1.26.12)
#
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: python3.10 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: seaborn in /usr/local/lib/python3.10/site-packages (0.12.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in /usr/local/lib/python3.10/site-packages (from seaborn) (1.24.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in /usr/local/lib/python3.10/site-packages (from seaborn) (3.7.1)
# Requirement already satisfied: pandas>=0.25 in /usr/local/lib/python3.10/site-packages (from seaborn) (1.5.3)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.38.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.4.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.0.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (21.3)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/site-packages (from pandas>=0.25->seaborn) (2022.6)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
#
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: python3.10 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/site-packages (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/site-packages (from matplotlib) (1.0.7)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/site-packages (from matplotlib) (4.38.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/site-packages (from matplotlib) (1.24.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/site-packages (from matplotlib) (21.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
#
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: python3.10 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from pymongo import MongoClient
# imports and stuff
myclient = MongoClient("mongodb+srv://HonourThesis:XZJXwB8NNdHIoxGw@cluster0.no1barz.mongodb.net/test")
db = myclient['GSoC']
Users = db['Users']
Pulls = db['PullsREAL']
Comments = db['CommentsREAL']

user_df = pd.DataFrame(list(Users.find()))
pulls_df = pd.DataFrame(list(Pulls.find()))
comments_df = pd.DataFrame(list(Comments.find()))
# Convert JSON data to DataFrame using json_normalize()
#df2 = pd.json_normalize(comments_df['user'])
comments_df = pd.concat([pd.json_normalize(comments_df['user']), comments_df.drop(['user'], axis=1)], axis=1)
comments_df
# Out:
#                 login        id               node_id  \
# 0              saghul    317464  MDQ6VXNlcjMxNzQ2NA==
# 1              saghul    317464  MDQ6VXNlcjMxNzQ2NA==
# 2     SHIVAJIKUMAR007  55244409  MDQ6VXNlcjU1MjQ0NDA5
# 3              saghul    317464  MDQ6VXNlcjMxNzQ2NA==
# 4     SHIVAJIKUMAR007  55244409  MDQ6VXNlcjU1MjQ0NDA5
# ...               ...       ...                   ...
# 6300  ItsAdityaKSingh  69353350  MDQ6VXNlcjY5MzUzMzUw
# 6301           nb9960  63557873  MDQ6VXNlcjYzNTU3ODcz
# 6302           nb9960  63557873  MDQ6VXNlcjYzNTU3ODcz
# 6303  ItsAdityaKSingh  69353350  MDQ6VXNlcjY5MzUzMzUw
# 6304  ItsAdityaKSingh  69353350  MDQ6VXNlcjY5MzUzMzUw
#
#                                              avatar_url gravatar_id  \
# 0     https://avatars.githubusercontent.com/u/317464...
# 1     https://avatars.githubusercontent.com/u/317464...
# 2     https://avatars.githubusercontent.com/u/552444...
# 3     https://avatars.githubusercontent.com/u/317464...
# 4     https://avatars.githubusercontent.com/u/552444...
# ...                                                 ...         ...
# 6300  https://avatars.githubusercontent.com/u/693533...
# 6301  https://avatars.githubusercontent.com/u/635578...
# 6302  https://avatars.githubusercontent.com/u/635578...
# 6303  https://avatars.githubusercontent.com/u/693533...
# 6304  https://avatars.githubusercontent.com/u/693533...
#
#                                                url  \
# 0              https://api.github.com/users/saghul
# 1              https://api.github.com/users/saghul
# 2     https://api.github.com/users/SHIVAJIKUMAR007
# 3              https://api.github.com/users/saghul
# 4     https://api.github.com/users/SHIVAJIKUMAR007
# ...                                            ...
# 6300  https://api.github.com/users/ItsAdityaKSingh
# 6301           https://api.github.com/users/nb9960
# 6302           https://api.github.com/users/nb9960
# 6303  https://api.github.com/users/ItsAdityaKSingh
# 6304  https://api.github.com/users/ItsAdityaKSingh
#
#                                 html_url  \
# 0              https://github.com/saghul
# 1              https://github.com/saghul
# 2     https://github.com/SHIVAJIKUMAR007
# 3              https://github.com/saghul
# 4     https://github.com/SHIVAJIKUMAR007
# ...                                  ...
# 6300  https://github.com/ItsAdityaKSingh
# 6301           https://github.com/nb9960
# 6302           https://github.com/nb9960
# 6303  https://github.com/ItsAdityaKSingh
# 6304  https://github.com/ItsAdityaKSingh
#
#                                           followers_url  \
# 0         https://api.github.com/users/saghul/followers
# 1         https://api.github.com/users/saghul/followers
# 2     https://api.github.com/users/SHIVAJIKUMAR007/f...
# 3         https://api.github.com/users/saghul/followers
# 4     https://api.github.com/users/SHIVAJIKUMAR007/f...
# ...                                                 ...
# 6300  https://api.github.com/users/ItsAdityaKSingh/f...
# 6301      https://api.github.com/users/nb9960/followers
# 6302      https://api.github.com/users/nb9960/followers
# 6303  https://api.github.com/users/ItsAdityaKSingh/f...
# 6304  https://api.github.com/users/ItsAdityaKSingh/f...
#
#                                           following_url  \
# 0     https://api.github.com/users/saghul/following{...
# 1     https://api.github.com/users/saghul/following{...
# 2     https://api.github.com/users/SHIVAJIKUMAR007/f...
# 3     https://api.github.com/users/saghul/following{...
# 4     https://api.github.com/users/SHIVAJIKUMAR007/f...
# ...                                                 ...
# 6300  https://api.github.com/users/ItsAdityaKSingh/f...
# 6301  https://api.github.com/users/nb9960/following{...
# 6302  https://api.github.com/users/nb9960/following{...
# 6303  https://api.github.com/users/ItsAdityaKSingh/f...
# 6304  https://api.github.com/users/ItsAdityaKSingh/f...
#
#                                               gists_url  ...  \
# 0     https://api.github.com/users/saghul/gists{/gis...  ...
# 1     https://api.github.com/users/saghul/gists{/gis...  ...
# 2     https://api.github.com/users/SHIVAJIKUMAR007/g...  ...
# 3     https://api.github.com/users/saghul/gists{/gis...  ...
# 4     https://api.github.com/users/SHIVAJIKUMAR007/g...  ...
# ...                                                 ...  ...
# 6300  https://api.github.com/users/ItsAdityaKSingh/g...  ...
# 6301  https://api.github.com/users/nb9960/gists{/gis...  ...
# 6302  https://api.github.com/users/nb9960/gists{/gis...  ...
# 6303  https://api.github.com/users/ItsAdityaKSingh/g...  ...
# 6304  https://api.github.com/users/ItsAdityaKSingh/g...  ...
#
#                   node_id            created_at            updated_at  \
# 0     IC_kwDOApPXJ85JT8bt  2022-08-29T08:45:02Z  2022-08-29T08:45:02Z
# 1     IC_kwDOApPXJ85KIBDH  2022-09-12T11:39:55Z  2022-09-12T11:39:55Z
# 2     IC_kwDOApPXJ85KIVOn  2022-09-12T12:53:30Z  2022-09-12T12:53:50Z
# 3     IC_kwDOApPXJ85Lfyrb  2022-10-04T08:58:48Z  2022-10-04T08:58:48Z
# 4     IC_kwDOApPXJ85Lhzrm  2022-10-04T15:07:39Z  2022-10-04T15:08:04Z
# ...                   ...                   ...                   ...
# 6300  IC_kwDOFSH8b84_A6A7  2022-03-02T17:43:19Z  2022-03-02T17:43:19Z
# 6301  IC_kwDOFSH8b84_AlzW  2022-03-02T16:27:42Z  2022-03-02T16:27:42Z
# 6302  IC_kwDOFSH8b84_AjPg  2022-03-02T16:17:26Z  2022-03-02T16:17:26Z
# 6303  IC_kwDOFSH8b85FdPsK  2022-06-24T07:38:19Z  2022-06-24T07:38:19Z
# 6304  IC_kwDOFSH8b85QEJ0F  2022-12-08T19:43:25Z  2022-12-08T19:43:25Z
#
#      author_association                                               body  \
# 0                MEMBER   Can you please paste a link to the blur example?
# 1                MEMBER  @SHIVAJIKUMAR007 don't we need to release the ...
# 2           CONTRIBUTOR                               yes, you are right.
# 3                MEMBER  Congrats @SHIVAJIKUMAR007 this is now merged a...
# 4           CONTRIBUTOR  Thanks, @saghul and @tmoldovan8x8 for all the ...
# ...                 ...                                                ...
# 6300       COLLABORATOR       Not necessary as PR #114 already handles it.
# 6301       COLLABORATOR                      Please resolve the conflicts.
# 6302       COLLABORATOR  You removed gradle files and there some confli...
# 6303       COLLABORATOR  #161 Already resolves the changes proposed in ...
# 6304       COLLABORATOR               Closing as already resolved in #161!
#
#                                               reactions  \
# 0     {'url': 'https://api.github.com/repos/react-na...
# 1     {'url': 'https://api.github.com/repos/react-na...
# 2     {'url': 'https://api.github.com/repos/react-na...
# 3     {'url': 'https://api.github.com/repos/react-na...
# 4     {'url': 'https://api.github.com/repos/react-na...
# ...                                                 ...
# 6300  {'url': 'https://api.github.com/repos/CCExtrac...
# 6301  {'url': 'https://api.github.com/repos/CCExtrac...
# 6302  {'url': 'https://api.github.com/repos/CCExtrac...
# 6303  {'url': 'https://api.github.com/repos/CCExtrac...
# 6304  {'url': 'https://api.github.com/repos/CCExtrac...
#
#      performed_via_github_app      mentee_name           owner_name  \
# 0                        None  SHIVAJIKUMAR007  react-native-webrtc
# 1                        None  SHIVAJIKUMAR007  react-native-webrtc
# 2                        None  SHIVAJIKUMAR007  react-native-webrtc
# 3                        None  SHIVAJIKUMAR007  react-native-webrtc
# 4                        None  SHIVAJIKUMAR007  react-native-webrtc
# ...                       ...              ...                  ...
# 6300                     None  ItsAdityaKSingh          CCExtractor
# 6301                     None  ItsAdityaKSingh          CCExtractor
# 6302                     None  ItsAdityaKSingh          CCExtractor
# 6303                     None  ItsAdityaKSingh          CCExtractor
# 6304                     None  ItsAdityaKSingh          CCExtractor
#
#                 repo_name
# 0     react-native-webrtc
# 1     react-native-webrtc
# 2     react-native-webrtc
# 3     react-native-webrtc
# 4     react-native-webrtc
# ...                   ...
# 6300               beacon
# 6301               beacon
# 6302               beacon
# 6303               beacon
# 6304               beacon
#
# [6305 rows x 33 columns]

# %%
user_df = user_df.drop(columns=['subscriptions_url', 'organizations_url'])
user_df
# Out:
#                           _id            login        id  \
# 0    63c048eee5a00d9932c67336  SHIVAJIKUMAR007  55244409
# 1    63c048eee5a00d9932c67337     tmoldovan8x8  62697631
# 2    63c048efe5a00d9932c67338           saghul    317464
# 3    63b3ac46e522528f6fdafbb7       Riken-Shah  63820270
# 4    63b3ac47e522528f6fdafbb8        timabbott   2746074
# ..                        ...              ...       ...
# 315  63b38a3e56adab3ffd7680ba   techiepriyansh  26199781
# 316  63b38a3f56adab3ffd7680bb         clayjohn  16521339
# 317  63b38a4056adab3ffd7680bc            JFonS   4402304
# 318  63bfbc37be4bec0503c05389  ItsAdityaKSingh  69353350
# 319  63bfbc37be4bec0503c0538a           nb9960  63557873
#
#                   node_id                                         avatar_url  \
# 0    MDQ6VXNlcjU1MjQ0NDA5  https://avatars.githubusercontent.com/u/552444...
# 1    MDQ6VXNlcjYyNjk3NjMx  https://avatars.githubusercontent.com/u/626976...
# 2    MDQ6VXNlcjMxNzQ2NA==  https://avatars.githubusercontent.com/u/317464...
# 3    MDQ6VXNlcjYzODIwMjcw  https://avatars.githubusercontent.com/u/638202...
# 4    MDQ6VXNlcjI3NDYwNzQ=  https://avatars.githubusercontent.com/u/274607...
# ..                    ...                                                ...
# 315  MDQ6VXNlcjI2MTk5Nzgx  https://avatars.githubusercontent.com/u/261997...
# 316  MDQ6VXNlcjE2NTIxMzM5  https://avatars.githubusercontent.com/u/165213...
# 317  MDQ6VXNlcjQ0MDIzMDQ=  https://avatars.githubusercontent.com/u/440230...
# 318  MDQ6VXNlcjY5MzUzMzUw  https://avatars.githubusercontent.com/u/693533...
# 319  MDQ6VXNlcjYzNTU3ODcz  https://avatars.githubusercontent.com/u/635578...
#
#     gravatar_id                                           url  \
# 0                https://api.github.com/users/SHIVAJIKUMAR007
# 1                   https://api.github.com/users/tmoldovan8x8
# 2                         https://api.github.com/users/saghul
# 3                     https://api.github.com/users/Riken-Shah
# 4                      https://api.github.com/users/timabbott
# ..          ...                                           ...
# 315               https://api.github.com/users/techiepriyansh
# 316                     https://api.github.com/users/clayjohn
# 317                        https://api.github.com/users/JFonS
# 318              https://api.github.com/users/ItsAdityaKSingh
# 319                       https://api.github.com/users/nb9960
#
#                                html_url  \
# 0    https://github.com/SHIVAJIKUMAR007
# 1       https://github.com/tmoldovan8x8
# 2             https://github.com/saghul
# 3         https://github.com/Riken-Shah
# 4          https://github.com/timabbott
# ..                                  ...
# 315   https://github.com/techiepriyansh
# 316         https://github.com/clayjohn
# 317            https://github.com/JFonS
# 318  https://github.com/ItsAdityaKSingh
# 319           https://github.com/nb9960
#
#                                          followers_url  \
# 0    https://api.github.com/users/SHIVAJIKUMAR007/f...
# 1    https://api.github.com/users/tmoldovan8x8/foll...
# 2        https://api.github.com/users/saghul/followers
# 3    https://api.github.com/users/Riken-Shah/followers
# 4     https://api.github.com/users/timabbott/followers
# ..                                                 ...
# 315  https://api.github.com/users/techiepriyansh/fo...
# 316    https://api.github.com/users/clayjohn/followers
# 317       https://api.github.com/users/JFonS/followers
# 318  https://api.github.com/users/ItsAdityaKSingh/f...
# 319      https://api.github.com/users/nb9960/followers
#
#                                          following_url  ... following  \
# 0    https://api.github.com/users/SHIVAJIKUMAR007/f...  ...         5
# 1    https://api.github.com/users/tmoldovan8x8/foll...  ...         0
# 2    https://api.github.com/users/saghul/following{...  ...        88
# 3    https://api.github.com/users/Riken-Shah/follow...  ...        34
# 4    https://api.github.com/users/timabbott/followi...  ...         6
# ..                                                 ...  ...       ...
# 315  https://api.github.com/users/techiepriyansh/fo...  ...        17
# 316  https://api.github.com/users/clayjohn/followin...  ...         0
# 317  https://api.github.com/users/JFonS/following{/...  ...         4
# 318  https://api.github.com/users/ItsAdityaKSingh/f...  ...        22
# 319  https://api.github.com/users/nb9960/following{...  ...        30
#
#                created_at            updated_at mentee mentor pr/issue  \
# 0    2019-09-12T13:54:29Z  2022-07-20T16:37:50Z   True  False    False
# 1    2020-03-26T10:30:44Z  2023-01-04T07:45:35Z  False   True    False
# 2    2010-06-29T13:49:31Z  2023-01-11T08:48:38Z  False   True    False
# 3    2020-04-16T21:34:43Z  2022-12-18T06:02:19Z   True  False    False
# 4    2012-11-07T21:18:39Z  2022-06-20T18:37:39Z  False   True    False
# ..                    ...                   ...    ...    ...      ...
# 315  2017-03-05T11:53:28Z  2022-12-20T12:51:45Z   True  False    False
# 316  2016-01-02T23:23:43Z  2023-01-02T23:27:59Z  False   True    False
# 317  2013-05-11T07:16:16Z  2023-01-01T20:28:28Z  False   True    False
# 318  2020-08-07T13:18:16Z  2022-11-27T17:34:44Z   True  False    False
# 319  2020-04-12T18:28:04Z  2023-01-09T13:56:11Z  False   True    False
#
#      comment           owner_name            repo_name pair_id
# 0      False  react-native-webrtc  react-native-webrtc       1
# 1      False  react-native-webrtc  react-native-webrtc       1
# 2      False  react-native-webrtc  react-native-webrtc       1
# 3      False                zulip                zulip       2
# 4      False                zulip                zulip       2
# ..       ...                  ...                  ...     ...
# 315    False          godotengine                godot     119
# 316    False          godotengine                godot     119
# 317    False          godotengine                godot     119
# 318    False          CCExtractor               beacon     120
# 319    False          CCExtractor               beacon     120
#
# [320 rows x 38 columns]

# %%
#pulls_df = pd.concat([pd.json_normalize(pulls_df['pull_request']), pulls_df.drop(['pull_request'], axis=1)], axis=1)
pulls_df.rename(columns={pulls_df.columns[1]: "issue_url" }, inplace = True)
pulls_df
# Out:
#                            _id  \
# 0     6417db47293807e5b39873d5
# 1     6417db47293807e5b39873d6
# 2     6417db48293807e5b39873d7
# 3     6417db49293807e5b39873d8
# 4     6417db49293807e5b39873d9
# ...                        ...
# 1460  6417ddb8293807e5b3987989
# 1461  6417ddb8293807e5b398798a
# 1462  6417ddb8293807e5b398798b
# 1463  6417ddb8293807e5b398798c
# 1464  6417ddb8293807e5b398798d
#
#                                               issue_url  \
# 0     https://api.github.com/repos/react-native-webr...
# 1     https://api.github.com/repos/react-native-webr...
# 2     https://api.github.com/repos/zulip/zulip/issue...
# 3     https://api.github.com/repos/zulip/zulip/issue...
# 4     https://api.github.com/repos/zulip/zulip/issue...
# ...                                                 ...
# 1460  https://api.github.com/repos/CCExtractor/beaco...
# 1461  https://api.github.com/repos/CCExtractor/beaco...
# 1462  https://api.github.com/repos/CCExtractor/beaco...
# 1463  https://api.github.com/repos/CCExtractor/beaco...
# 1464  https://api.github.com/repos/CCExtractor/beaco...
#
#                                          repository_url  \
# 0     https://api.github.com/repos/react-native-webr...
# 1     https://api.github.com/repos/react-native-webr...
# 2              https://api.github.com/repos/zulip/zulip
# 3              https://api.github.com/repos/zulip/zulip
# 4              https://api.github.com/repos/zulip/zulip
# ...                                                 ...
# 1460    https://api.github.com/repos/CCExtractor/beacon
# 1461    https://api.github.com/repos/CCExtractor/beacon
# 1462    https://api.github.com/repos/CCExtractor/beacon
# 1463    https://api.github.com/repos/CCExtractor/beacon
# 1464    https://api.github.com/repos/CCExtractor/beacon
#
#                                              labels_url  \
# 0     https://api.github.com/repos/react-native-webr...
# 1     https://api.github.com/repos/react-native-webr...
# 2     https://api.github.com/repos/zulip/zulip/issue...
# 3     https://api.github.com/repos/zulip/zulip/issue...
# 4     https://api.github.com/repos/zulip/zulip/issue...
# ...                                                 ...
# 1460  https://api.github.com/repos/CCExtractor/beaco...
# 1461  https://api.github.com/repos/CCExtractor/beaco...
# 1462  https://api.github.com/repos/CCExtractor/beaco...
# 1463  https://api.github.com/repos/CCExtractor/beaco...
# 1464  https://api.github.com/repos/CCExtractor/beaco...
#
#                                            comments_url  \
# 0     https://api.github.com/repos/react-native-webr...
# 1     https://api.github.com/repos/react-native-webr...
# 2     https://api.github.com/repos/zulip/zulip/issue...
# 3     https://api.github.com/repos/zulip/zulip/issue...
# 4     https://api.github.com/repos/zulip/zulip/issue...
# ...                                                 ...
# 1460  https://api.github.com/repos/CCExtractor/beaco...
# 1461  https://api.github.com/repos/CCExtractor/beaco...
# 1462  https://api.github.com/repos/CCExtractor/beaco...
# 1463  https://api.github.com/repos/CCExtractor/beaco...
# 1464  https://api.github.com/repos/CCExtractor/beaco...
#
#                                              events_url  \
# 0     https://api.github.com/repos/react-native-webr...
# 1     https://api.github.com/repos/react-native-webr...
# 2     https://api.github.com/repos/zulip/zulip/issue...
# 3     https://api.github.com/repos/zulip/zulip/issue...
# 4     https://api.github.com/repos/zulip/zulip/issue...
# ...                                                 ...
# 1460  https://api.github.com/repos/CCExtractor/beaco...
# 1461  https://api.github.com/repos/CCExtractor/beaco...
# 1462  https://api.github.com/repos/CCExtractor/beaco...
# 1463  https://api.github.com/repos/CCExtractor/beaco...
# 1464  https://api.github.com/repos/CCExtractor/beaco...
#
#                                                html_url          id  \
# 0     https://github.com/react-native-webrtc/react-n...  1348873503
# 1     https://github.com/react-native-webrtc/react-n...  1307069272
# 2             https://github.com/zulip/zulip/pull/24463  1596949132
# 3             https://github.com/zulip/zulip/pull/24408  1588703344
# 4             https://github.com/zulip/zulip/pull/23356  1425364764
# ...                                                 ...         ...
# 1460     https://github.com/CCExtractor/beacon/pull/116  1124494921
# 1461     https://github.com/CCExtractor/beacon/pull/115  1124494890
# 1462     https://github.com/CCExtractor/beacon/pull/112  1121615045
# 1463     https://github.com/CCExtractor/beacon/pull/111  1121554082
# 1464     https://github.com/CCExtractor/beacon/pull/106  1118160253
#
#                   node_id  number  ...  \
# 0     PR_kwDOApPXJ849sJro    1176  ...
# 1     PR_kwDOApPXJ847hcMU    1169  ...
# 2     PR_kwDOApKUbc5KnIX5   24463  ...
# 3     PR_kwDOApKUbc5KLxiv   24408  ...
# 4     PR_kwDOApKUbc5Bpubq   23356  ...
# ...                   ...     ...  ...
# 1460  PR_kwDOFSH8b84yGSKn     116  ...
# 1461  PR_kwDOFSH8b84yGSKN     115  ...
# 1462  PR_kwDOFSH8b84x82-5     112  ...
# 1463  PR_kwDOFSH8b84x8qTz     111  ...
# 1464  PR_kwDOFSH8b84xxk9C     106  ...
#
#                                            pull_request  \
# 0     {'url': 'https://api.github.com/repos/react-na...
# 1     {'url': 'https://api.github.com/repos/react-na...
# 2     {'url': 'https://api.github.com/repos/zulip/zu...
# 3     {'url': 'https://api.github.com/repos/zulip/zu...
# 4     {'url': 'https://api.github.com/repos/zulip/zu...
# ...                                                 ...
# 1460  {'url': 'https://api.github.com/repos/CCExtrac...
# 1461  {'url': 'https://api.github.com/repos/CCExtrac...
# 1462  {'url': 'https://api.github.com/repos/CCExtrac...
# 1463  {'url': 'https://api.github.com/repos/CCExtrac...
# 1464  {'url': 'https://api.github.com/repos/CCExtrac...
#
#                                                    body  \
# 0     this is the video effect registry\r\n\r\nto cr...
# 1     I have created a class by implementing VideoPr...
# 2     Currently, `drafts.ts` suffers from a non-dete...
# 3     This has always been in the global namespace. ...
# 4     We were getting the `undefined` error when acc...
# ...                                                 ...
# 1460  Partly fixes #46 \r\n\r\nDescribe the changes ...
# 1461  Partly fixes #46 \r\n\r\nDescribe the changes ...
# 1462  Fixes #52 \r\n\r\nDescribe the changes you hav...
# 1463  Fixes #110 \r\n\r\nBefore            |  After\...
# 1464  A small fix left out in PR #63. My apologies f...
#
#                                               reactions  \
# 0     {'url': 'https://api.github.com/repos/react-na...
# 1     {'url': 'https://api.github.com/repos/react-na...
# 2     {'url': 'https://api.github.com/repos/zulip/zu...
# 3     {'url': 'https://api.github.com/repos/zulip/zu...
# 4     {'url': 'https://api.github.com/repos/zulip/zu...
# ...                                                 ...
# 1460  {'url': 'https://api.github.com/repos/CCExtrac...
# 1461  {'url': 'https://api.github.com/repos/CCExtrac...
# 1462  {'url': 'https://api.github.com/repos/CCExtrac...
# 1463  {'url': 'https://api.github.com/repos/CCExtrac...
# 1464  {'url': 'https://api.github.com/repos/CCExtrac...
#
#                                            timeline_url  \
# 0     https://api.github.com/repos/react-native-webr...
# 1     https://api.github.com/repos/react-native-webr...
# 2     https://api.github.com/repos/zulip/zulip/issue...
# 3     https://api.github.com/repos/zulip/zulip/issue...
# 4     https://api.github.com/repos/zulip/zulip/issue...
# ...                                                 ...
# 1460  https://api.github.com/repos/CCExtractor/beaco...
# 1461  https://api.github.com/repos/CCExtractor/beaco...
# 1462  https://api.github.com/repos/CCExtractor/beaco...
# 1463  https://api.github.com/repos/CCExtractor/beaco...
# 1464  https://api.github.com/repos/CCExtractor/beaco...
#
#       performed_via_github_app state_reason score      mentee_name  \
# 0                         None         None   1.0  SHIVAJIKUMAR007
# 1                         None         None   1.0  SHIVAJIKUMAR007
# 2                         None         None   1.0       Riken-Shah
# 3                         None         None   1.0       Riken-Shah
# 4                         None         None   1.0       Riken-Shah
# ...                        ...          ...   ...              ...
# 1460                      None         None   1.0  ItsAdityaKSingh
# 1461                      None         None   1.0  ItsAdityaKSingh
# 1462                      None         None   1.0  ItsAdityaKSingh
# 1463                      None         None   1.0  ItsAdityaKSingh
# 1464                      None         None   1.0  ItsAdityaKSingh
#
#                owner_name            repo_name
# 0     react-native-webrtc  react-native-webrtc
# 1     react-native-webrtc  react-native-webrtc
# 2                   zulip                zulip
# 3                   zulip                zulip
# 4                   zulip                zulip
# ...                   ...                  ...
# 1460          CCExtractor               beacon
# 1461          CCExtractor               beacon
# 1462          CCExtractor               beacon
# 1463          CCExtractor               beacon
# 1464          CCExtractor               beacon
#
# [1465 rows x 35 columns]

# %%
# Define custom function to apply to each group
def add_false_usernames(group):
    false_usernames = group.loc[group['mentee'] == False, 'login']
    if false_usernames.empty:
        return group[group['mentee']]
    else:
        group['mentor_login'] = ', '.join(false_usernames)
        return group[group['mentee']]

# Group data by 'ids' and apply custom function
mentors_mentees = user_df.groupby('pair_id').apply(add_false_usernames).reset_index(drop=True)
mentors_mentees = mentors_mentees.drop(['_id', 'node_id', 'id', 'bio', 'html_url', 'received_events_url', 
                                        'blog', 'email', 'hireable', 'twitter_username', 'events_url', 'url', 
                                        'company', 'site_admin', 'gists_url', 'starred_url', 'repos_url', 'gravatar_id', 
                                        'following_url', 'followers_url', 'avatar_url', 'pr/issue', 'comment', 'public_gists',
                                        'followers', 'following', 'created_at', 'updated_at', 'mentee',
                                        'public_repos', 'mentor', 'location', 'type'], axis=1)
# Print result, df of mentors with their mentor
mentors_mentees.columns = ['mentee_name' if x=='name' else x for x in mentors_mentees.columns]
mentors_mentees
# Out:
#                  login         mentee_name           owner_name  \
# 0      SHIVAJIKUMAR007             SHIVAJI  react-native-webrtc
# 1           Riken-Shah          Riken Shah                zulip
# 2              alexcsf           Alexandre                jitsi
# 3             pchengma        Pengcheng Ma               apache
# 4           augsaksham     Saksham Dwivedi          CCExtractor
# ..                 ...                 ...                  ...
# 113  devarsh-mavani-19      Devarsh Mavani              mit-cml
# 114        Tarun-Arora         Tarun Arora          CCExtractor
# 115      preetvadaliya   Preet P. Vadaliya              mit-cml
# 116     techiepriyansh      Priyansh Rathi          godotengine
# 117    ItsAdityaKSingh  Aditya Kumar Singh          CCExtractor
#
#                repo_name  pair_id                        mentor_login
# 0    react-native-webrtc        1                tmoldovan8x8, saghul
# 1                  zulip        2                           timabbott
# 2      jitsi-videobridge        3                             bgrozev
# 3    incubator-eventmesh        4                             xwm1992
# 4            Rekognition        5                        PulkitMishra
# ..                   ...      ...                                 ...
# 113  appinventor-sources      116                              jisqyv
# 114      sample-platform      117  thealphadollar, canihavesomecoffee
# 115  appinventor-sources      118   ewpatton, preetvadaliya, ewpatton
# 116                godot      119                     clayjohn, JFonS
# 117               beacon      120                              nb9960
#
# [118 rows x 6 columns]

# %%
# pulls after a certain date to measure success
success = pulls_df[pd.to_datetime(pulls_df['closed_at']) > '2022-9-12'].groupby(['mentee_name']).size()
success = success.to_frame().reset_index()
success.columns = ['mentee_name', 'number_of_pulls']
# sort the DataFrame by the 'age' column in descending order
success = success.sort_values(by='number_of_pulls', ascending=False)
average_success_pulls = success['number_of_pulls'].mean()
print(average_success_pulls)
# Out:
# 12.908163265306122

# %%
success
# Out:
#      mentee_name  number_of_pulls
# 63    iuliadmtru               60
# 42     arsalan0c               30
# 68  lucaferranti               30
# 15      HaiqiQin               29
# 54   dheerajodha               29
# ..           ...              ...
# 58      ffyuanda                1
# 94    xinran1228                1
# 37      Ziy1-Tan                1
# 40     alive2020                1
# 88    srdeotarse                1
#
# [98 rows x 2 columns]

# %%
#plot success
import matplotlib.pyplot as plt
# create a bar chart
ax = success.plot(kind='bar', rot=0)
plt.show()

# %%
# successful mentor mentee
success_mentor = mentors_mentees[mentors_mentees['login'].isin(success['mentee_name'])]
success_mentor['mentor_login'] = success_mentor['mentor_login'].str.split(', ')
success_mentor = success_mentor.explode('mentor_login')
success_mentor
# Out:
# /var/folders/8z/s8b92l813mb_lr9td4d79jmh0000gn/T/ipykernel_48598/317145389.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   success_mentor['mentor_login'] = success_mentor['mentor_login'].str.split(', ')
#                login         mentee_name           owner_name  \
# 0    SHIVAJIKUMAR007             SHIVAJI  react-native-webrtc
# 0    SHIVAJIKUMAR007             SHIVAJI  react-native-webrtc
# 1         Riken-Shah          Riken Shah                zulip
# 2            alexcsf           Alexandre                jitsi
# 3           pchengma        Pengcheng Ma               apache
# ..               ...                 ...                  ...
# 115    preetvadaliya   Preet P. Vadaliya              mit-cml
# 115    preetvadaliya   Preet P. Vadaliya              mit-cml
# 116   techiepriyansh      Priyansh Rathi          godotengine
# 116   techiepriyansh      Priyansh Rathi          godotengine
# 117  ItsAdityaKSingh  Aditya Kumar Singh          CCExtractor
#
#                repo_name  pair_id   mentor_login
# 0    react-native-webrtc        1   tmoldovan8x8
# 0    react-native-webrtc        1         saghul
# 1                  zulip        2      timabbott
# 2      jitsi-videobridge        3        bgrozev
# 3    incubator-eventmesh        4        xwm1992
# ..                   ...      ...            ...
# 115  appinventor-sources      118  preetvadaliya
# 115  appinventor-sources      118       ewpatton
# 116                godot      119       clayjohn
# 116                godot      119          JFonS
# 117               beacon      120         nb9960
#
# [170 rows x 6 columns]

# %%
# find unsuccessful people
unsuccessful = user_df[~user_df['login'].isin(success['mentee_name'])]
unsuccessful = unsuccessful[unsuccessful['mentor'] != True]
#unsuccessful = unsuccessful.to_frame().reset_index()
#unsuccessful.columns = ['mentee_name', 'total']
unsuccessful = unsuccessful.drop(['_id', 'id', 'html_url', 'gists_url', 'starred_url', 'repos_url', 'events_url', 'received_events_url',
                                  'type', 'node_id', 'avatar_url', 'gravatar_id', 'url', 'followers_url', 'following_url', 'following', 
                                  'created_at', 'updated_at', 'mentee', 'mentor', 'pr/issue', 'comment', 'owner_name', 'repo_name', 
                                  'site_admin', 'name', 'company', 'blog', 'location', 'email', 'hireable', 'bio', 'twitter_username',
                                  'public_repos', 'public_gists', 'followers', 'pair_id'], axis=1)
unsuccessful.columns = ['mentee_name']
unsuccessful
# Out:
#        mentee_name
# 11     ZhaoChuyang
# 25          mazrex
# 37   butterfly1924
# 41        razetime
# 59          sunxd3
# 62      ZeroDawn0D
# 79     mounilKshah
# 87      A-Wanderer
# 94         raosush
# 130       madrix01
# 150        ag-cdev
# 170    geekdanitek
# 179    tanruixiang
# 225          ZLBer
# 252    lowlypalace
# 279     lukekang98
# 284        Vitika9
# 299       mabelbot

# %%
# unsuccessful mentor mentee
unsuccess_mentor = mentors_mentees[~mentors_mentees['login'].isin(success['mentee_name'])]
unsuccess_mentor['mentor_login'] = unsuccess_mentor['mentor_login'].str.split(', ')
unsuccess_mentor = unsuccess_mentor.explode('mentor_login')
unsuccess_mentor
# Out:
# /var/folders/8z/s8b92l813mb_lr9td4d79jmh0000gn/T/ipykernel_48598/60903134.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   unsuccess_mentor['mentor_login'] = unsuccess_mentor['mentor_login'].str.split(', ')
#              login           mentee_name    owner_name  \
# 5      ZhaoChuyang              Chuyang         opencv
# 9           mazrex              Prashant       MariaDB
# 9           mazrex              Prashant       MariaDB
# 14   butterfly1924                 BAnon        apache
# 14   butterfly1924                 BAnon        apache
# 14   butterfly1924                 BAnon        apache
# 15        razetime               Raghu R        oracle
# 15        razetime               Raghu R        oracle
# 21          sunxd3            Xianda Sun    TuringLang
# 21          sunxd3            Xianda Sun    TuringLang
# 22      ZeroDawn0D        Umang Majumder    ZeroDawn0D
# 22      ZeroDawn0D        Umang Majumder    ZeroDawn0D
# 22      ZeroDawn0D        Umang Majumder    ZeroDawn0D
# 22      ZeroDawn0D        Umang Majumder    ZeroDawn0D
# 22      ZeroDawn0D        Umang Majumder    ZeroDawn0D
# 27     mounilKshah           Mounil Shah         zulip
# 27     mounilKshah           Mounil Shah         zulip
# 30      A-Wanderer                 Nanno
# 33         raosush  Sushanth Sathesh Rao          ruby
# 45        madrix01           Shlok Patel         zulip
# 54         ag-cdev                  None         jitsi
# 62     geekdanitek        Daniel Adedeji         jitsi
# 66     tanruixiang          Ruixiang Tan       MariaDB
# 66     tanruixiang          Ruixiang Tan       MariaDB
# 85           ZLBer                  None
# 94     lowlypalace                  None  activeloopai
# 94     lowlypalace                  None  activeloopai
# 94     lowlypalace                  None  activeloopai
# 103     lukekang98                  None
# 105        Vitika9           Vitika Soni   godotengine
# 105        Vitika9           Vitika Soni   godotengine
# 110       mabelbot                 Mabel        chaoss
# 110       mabelbot                 Mabel        chaoss
#
#                      repo_name  pair_id          mentor_login
# 5               opencv_contrib        6             kaingwade
# 9                       server       10             cvicentiu
# 9                       server       10                  an3l
# 14            apisix-dashboard       15          tzssangglass
# 14            apisix-dashboard       15             juzhiyuan
# 14            apisix-dashboard       15               bzp2010
# 15                 truffleruby       16                eregon
# 15                 truffleruby       16           aardvark179
# 21              SymbolicPPL.jl       22                 yebai
# 21              SymbolicPPL.jl       22           phipsgabler
# 22                       tRiad       23                dicook
# 22                       tRiad       23         harriet-mason
# 22                       tRiad       23               Abhi-1U
# 22                       tRiad       23                dicook
# 22                       tRiad       23               hturner
# 27                       zulip       28                neiljp
# 27                       zulip       28            Rohitth007
# 30                                   31      LaurenceLiZhixin
# 33                        rdoc       34               soutaro
# 45                       zulip       47               amanagr
# 54   jitsi-upload-integrations       57      aaronkvanmeerten
# 62          jitsi-meet-vue-sdk       65                saghul
# 66                      server       69  mariadb-RuchaDeodhar
# 66                      server       69         sanja-byelkin
# 85                                   88      LaurenceLiZhixin
# 94                    deeplake       97           davidbuniat
# 94                    deeplake       97         farizrahman4u
# 94                    deeplake       97              mikayelh
# 103                                 106            peterccarl
# 105                      godot      108             akien-mga
# 105                      godot      108                KoBeWi
# 110                  community      113                 klumb
# 110                  community      113             vchrombie

# %%
# pulls during project dates
project_pulls = pulls_df[(pd.to_datetime(pulls_df['closed_at']) >= '2021-6-07') & (pd.to_datetime(pulls_df['closed_at']) <= '2021-8-30')]
#project_pulls.columns = ['urlppp' if x=='url' else x for x in project_pulls.columns]
project_pulls
# Out:
#                            _id  \
# 31    6417db49293807e5b39873f4
# 316   6417dbae293807e5b3987511
# 505   6417dc07293807e5b39875ce
# 506   6417dc07293807e5b39875cf
# 1414  6417ddb4293807e5b398795b
#
#                                               issue_url  \
# 31    https://api.github.com/repos/zulip/zulip/issue...
# 316   https://api.github.com/repos/godotengine/godot...
# 505   https://api.github.com/repos/chaoss/website/is...
# 506   https://api.github.com/repos/chaoss/website/is...
# 1414  https://api.github.com/repos/mit-cml/appinvent...
#
#                                          repository_url  \
# 31             https://api.github.com/repos/zulip/zulip
# 316      https://api.github.com/repos/godotengine/godot
# 505         https://api.github.com/repos/chaoss/website
# 506         https://api.github.com/repos/chaoss/website
# 1414  https://api.github.com/repos/mit-cml/appinvent...
#
#                                              labels_url  \
# 31    https://api.github.com/repos/zulip/zulip/issue...
# 316   https://api.github.com/repos/godotengine/godot...
# 505   https://api.github.com/repos/chaoss/website/is...
# 506   https://api.github.com/repos/chaoss/website/is...
# 1414  https://api.github.com/repos/mit-cml/appinvent...
#
#                                            comments_url  \
# 31    https://api.github.com/repos/zulip/zulip/issue...
# 316   https://api.github.com/repos/godotengine/godot...
# 505   https://api.github.com/repos/chaoss/website/is...
# 506   https://api.github.com/repos/chaoss/website/is...
# 1414  https://api.github.com/repos/mit-cml/appinvent...
#
#                                              events_url  \
# 31    https://api.github.com/repos/zulip/zulip/issue...
# 316   https://api.github.com/repos/godotengine/godot...
# 505   https://api.github.com/repos/chaoss/website/is...
# 506   https://api.github.com/repos/chaoss/website/is...
# 1414  https://api.github.com/repos/mit-cml/appinvent...
#
#                                                html_url         id  \
# 31            https://github.com/zulip/zulip/pull/19571  970584667
# 316     https://github.com/godotengine/godot/pull/50135  936323989
# 505          https://github.com/chaoss/website/pull/645  971819575
# 506          https://github.com/chaoss/website/pull/629  942191081
# 1414  https://github.com/mit-cml/appinventor-sources...  914518331
#
#                                node_id  number  ...  \
# 31    MDExOlB1bGxSZXF1ZXN0NzEyNTE2OTgy   19571  ...
# 316   MDExOlB1bGxSZXF1ZXN0NjgzMDc1NTIw   50135  ...
# 505   MDExOlB1bGxSZXF1ZXN0NzEzNTA2MTM0     645  ...
# 506   MDExOlB1bGxSZXF1ZXN0Njg3OTUzOTYx     629  ...
# 1414  MDExOlB1bGxSZXF1ZXN0NjY0NDI2NDc3    2495  ...
#
#                                            pull_request  \
# 31    {'url': 'https://api.github.com/repos/zulip/zu...
# 316   {'url': 'https://api.github.com/repos/godoteng...
# 505   {'url': 'https://api.github.com/repos/chaoss/w...
# 506   {'url': 'https://api.github.com/repos/chaoss/w...
# 1414  {'url': 'https://api.github.com/repos/mit-cml/...
#
#                                                    body  \
# 31    PR for the issue #15948 \r\n\r\n**I have added...
# 316   This PR makes Tree call `update()` when adding...
# 505   Changes:\r\n\r\n- Create latest-release-notes....
# 506   The common WG already has a metric named `cont...
# 1414                                       Fixed #2494
#
#                                               reactions  \
# 31    {'url': 'https://api.github.com/repos/zulip/zu...
# 316   {'url': 'https://api.github.com/repos/godoteng...
# 505   {'url': 'https://api.github.com/repos/chaoss/w...
# 506   {'url': 'https://api.github.com/repos/chaoss/w...
# 1414  {'url': 'https://api.github.com/repos/mit-cml/...
#
#                                            timeline_url  \
# 31    https://api.github.com/repos/zulip/zulip/issue...
# 316   https://api.github.com/repos/godotengine/godot...
# 505   https://api.github.com/repos/chaoss/website/is...
# 506   https://api.github.com/repos/chaoss/website/is...
# 1414  https://api.github.com/repos/mit-cml/appinvent...
#
#       performed_via_github_app state_reason score    mentee_name   owner_name  \
# 31                        None         None   1.0     Riken-Shah        zulip
# 316                       None         None   1.0      trollodel  godotengine
# 505                       None         None   1.0        yash-yp       chaoss
# 506                       None         None   1.0        yash-yp       chaoss
# 1414                      None         None   1.0  preetvadaliya      mit-cml
#
#                 repo_name
# 31                  zulip
# 316                 godot
# 505               website
# 506               website
# 1414  appinventor-sources
#
# [5 rows x 35 columns]

# %%
# match comments with pulls to get the comments
# first get all the pr numbers into a column
comments_df['number'] = comments_df['issue_url'].str.rsplit('/', 1, expand=True)[1]
comments_df['number'] = pd.to_numeric(comments_df['number'], errors='coerce') 
# match
project_comments =  pd.merge(comments_df, project_pulls, on='issue_url', how='right')
#project_comments = project_comments.dropna()
project_comments = project_comments.drop(['id_x', 'node_id_x', 'avatar_url', 'starred_url', 'subscriptions_url', 'received_events_url',
                                          'gravatar_id', 'html_url_x', 'followers_url', 'organizations_url', 'repos_url', 'type',
                                          'pull_request', 'body_y', 'reactions_y', 'following_url', 'gists_url', 'performed_via_github_app_y',
                                          ], axis=1)

project_comments.columns = ['mentee_name' if x=='mentee_name_y' else x for x in project_comments.columns]
project_comments.columns = ['mentor_name' if x=='mentor_name_y' else x for x in project_comments.columns]
project_comments.columns = ['owner_name' if x=='owner_name_y' else x for x in project_comments.columns]
project_comments.columns = ['repo_name' if x=='repo_name_y' else x for x in project_comments.columns]
#project_comments = project_comments.drop_duplicates()
project_comments
# Out:
# /var/folders/8z/s8b92l813mb_lr9td4d79jmh0000gn/T/ipykernel_48598/1523226537.py:3: FutureWarning: In a future version of pandas all arguments of StringMethods.rsplit except for the argument 'pat' will be keyword-only.
#   comments_df['number'] = comments_df['issue_url'].str.rsplit('/', 1, expand=True)[1]
#                    login                                                url  \
# 0               madrix01              https://api.github.com/users/madrix01
# 1      abhijeetbodas2001     https://api.github.com/users/abhijeetbodas2001
# 2               madrix01              https://api.github.com/users/madrix01
# 3      abhijeetbodas2001     https://api.github.com/users/abhijeetbodas2001
# 4               madrix01              https://api.github.com/users/madrix01
# 5               madrix01              https://api.github.com/users/madrix01
# 6               madrix01              https://api.github.com/users/madrix01
# 7              akien-mga             https://api.github.com/users/akien-mga
# 8              akien-mga             https://api.github.com/users/akien-mga
# 9                    NaN                                                NaN
# 10                   NaN                                                NaN
# 11  AppInventorWorkerBee  https://api.github.com/users/AppInventorWorkerBee
# 12              ewpatton              https://api.github.com/users/ewpatton
#
#                                          events_url_x site_admin  \
# 0   https://api.github.com/users/madrix01/events{/...      False
# 1   https://api.github.com/users/abhijeetbodas2001...      False
# 2   https://api.github.com/users/madrix01/events{/...      False
# 3   https://api.github.com/users/abhijeetbodas2001...      False
# 4   https://api.github.com/users/madrix01/events{/...      False
# 5   https://api.github.com/users/madrix01/events{/...      False
# 6   https://api.github.com/users/madrix01/events{/...      False
# 7   https://api.github.com/users/akien-mga/events{...      False
# 8   https://api.github.com/users/akien-mga/events{...      False
# 9                                                 NaN        NaN
# 10                                                NaN        NaN
# 11  https://api.github.com/users/AppInventorWorker...      False
# 12  https://api.github.com/users/ewpatton/events{/...      False
#
#                        _id_x  \
# 0   6417ddf69c61aa4dd0bf622a
# 1   6417ddf69c61aa4dd0bf622b
# 2   6417ddf69c61aa4dd0bf622c
# 3   6417ddf69c61aa4dd0bf622d
# 4   6417ddf69c61aa4dd0bf622e
# 5   6417ddf69c61aa4dd0bf622f
# 6   6417ddf69c61aa4dd0bf6230
# 7   6417df089c61aa4dd0bf66bc
# 8   6417df089c61aa4dd0bf66bd
# 9                        NaN
# 10                       NaN
# 11  6417e34c9c61aa4dd0bf78fc
# 12  6417e34c9c61aa4dd0bf78fd
#
#                                                   url  \
# 0   https://api.github.com/repos/zulip/zulip/issue...
# 1   https://api.github.com/repos/zulip/zulip/issue...
# 2   https://api.github.com/repos/zulip/zulip/issue...
# 3   https://api.github.com/repos/zulip/zulip/issue...
# 4   https://api.github.com/repos/zulip/zulip/issue...
# 5   https://api.github.com/repos/zulip/zulip/issue...
# 6   https://api.github.com/repos/zulip/zulip/issue...
# 7   https://api.github.com/repos/godotengine/godot...
# 8   https://api.github.com/repos/godotengine/godot...
# 9                                                 NaN
# 10                                                NaN
# 11  https://api.github.com/repos/mit-cml/appinvent...
# 12  https://api.github.com/repos/mit-cml/appinvent...
#
#                                             issue_url          created_at_x  \
# 0   https://api.github.com/repos/zulip/zulip/issue...  2021-08-13T20:18:00Z
# 1   https://api.github.com/repos/zulip/zulip/issue...  2021-08-14T09:59:37Z
# 2   https://api.github.com/repos/zulip/zulip/issue...  2021-08-15T07:27:48Z
# 3   https://api.github.com/repos/zulip/zulip/issue...  2021-08-15T11:31:38Z
# 4   https://api.github.com/repos/zulip/zulip/issue...  2021-08-15T11:44:18Z
# 5   https://api.github.com/repos/zulip/zulip/issue...  2021-08-16T04:11:38Z
# 6   https://api.github.com/repos/zulip/zulip/issue...  2021-08-17T07:10:44Z
# 7   https://api.github.com/repos/godotengine/godot...  2021-07-13T07:03:43Z
# 8   https://api.github.com/repos/godotengine/godot...  2021-07-13T08:01:49Z
# 9   https://api.github.com/repos/chaoss/website/is...                   NaN
# 10  https://api.github.com/repos/chaoss/website/is...                   NaN
# 11  https://api.github.com/repos/mit-cml/appinvent...  2021-06-08T07:54:29Z
# 12  https://api.github.com/repos/mit-cml/appinvent...  2021-06-08T10:42:47Z
#
#             updated_at_x author_association_x  ...             closed_at  \
# 0   2021-08-14T05:18:52Z         COLLABORATOR  ...  2021-08-17T07:10:44Z
# 1   2021-08-14T09:59:37Z               MEMBER  ...  2021-08-17T07:10:44Z
# 2   2021-08-15T07:27:48Z         COLLABORATOR  ...  2021-08-17T07:10:44Z
# 3   2021-08-15T11:31:38Z               MEMBER  ...  2021-08-17T07:10:44Z
# 4   2021-08-15T11:44:18Z         COLLABORATOR  ...  2021-08-17T07:10:44Z
# 5   2021-08-16T04:12:32Z         COLLABORATOR  ...  2021-08-17T07:10:44Z
# 6   2021-08-17T07:10:44Z         COLLABORATOR  ...  2021-08-17T07:10:44Z
# 7   2021-07-13T07:03:43Z               MEMBER  ...  2021-07-13T07:03:40Z
# 8   2021-07-13T08:01:49Z               MEMBER  ...  2021-07-13T07:03:40Z
# 9                    NaN                  NaN  ...  2021-08-16T15:40:14Z
# 10                   NaN                  NaN  ...  2021-07-22T19:44:02Z
# 11  2021-06-08T07:54:29Z         COLLABORATOR  ...  2021-06-10T16:35:51Z
# 12  2021-06-08T10:42:47Z               MEMBER  ...  2021-06-10T16:35:51Z
#
#    author_association_y active_lock_reason  draft  \
# 0          COLLABORATOR               None  False
# 1          COLLABORATOR               None  False
# 2          COLLABORATOR               None  False
# 3          COLLABORATOR               None  False
# 4          COLLABORATOR               None  False
# 5          COLLABORATOR               None  False
# 6          COLLABORATOR               None  False
# 7                MEMBER               None  False
# 8                MEMBER               None  False
# 9                MEMBER               None  False
# 10               MEMBER               None  False
# 11         COLLABORATOR               None  False
# 12         COLLABORATOR               None  False
#
#                                          timeline_url state_reason  score  \
# 0   https://api.github.com/repos/zulip/zulip/issue...         None    1.0
# 1   https://api.github.com/repos/zulip/zulip/issue...         None    1.0
# 2   https://api.github.com/repos/zulip/zulip/issue...         None    1.0
# 3   https://api.github.com/repos/zulip/zulip/issue...         None    1.0
# 4   https://api.github.com/repos/zulip/zulip/issue...         None    1.0
# 5   https://api.github.com/repos/zulip/zulip/issue...         None    1.0
# 6   https://api.github.com/repos/zulip/zulip/issue...         None    1.0
# 7   https://api.github.com/repos/godotengine/godot...         None    1.0
# 8   https://api.github.com/repos/godotengine/godot...         None    1.0
# 9   https://api.github.com/repos/chaoss/website/is...         None    1.0
# 10  https://api.github.com/repos/chaoss/website/is...         None    1.0
# 11  https://api.github.com/repos/mit-cml/appinvent...         None    1.0
# 12  https://api.github.com/repos/mit-cml/appinvent...         None    1.0
#
#       mentee_name   owner_name            repo_name
# 0      Riken-Shah        zulip                zulip
# 1      Riken-Shah        zulip                zulip
# 2      Riken-Shah        zulip                zulip
# 3      Riken-Shah        zulip                zulip
# 4      Riken-Shah        zulip                zulip
# 5      Riken-Shah        zulip                zulip
# 6      Riken-Shah        zulip                zulip
# 7       trollodel  godotengine                godot
# 8       trollodel  godotengine                godot
# 9         yash-yp       chaoss              website
# 10        yash-yp       chaoss              website
# 11  preetvadaliya      mit-cml  appinventor-sources
# 12  preetvadaliya      mit-cml  appinventor-sources
#
# [13 rows x 47 columns]

# %%
# RQ1  total comments made by each mentee
mentee_comments = project_comments[project_comments['mentee_name'] == project_comments['login']].groupby(['mentee_name']).size()
mentee_comments = mentee_comments.reset_index()
mentee_comments
mentee_comments.columns = ['mentee_name', 'mentee comments']
mentee_comments_success = pd.merge(success, mentee_comments, how='left', on='mentee_name').fillna(0)
mentee_comments_success = mentee_comments_success.drop(['number_of_pulls'], axis=1)
mentee_comments_success.columns = ['mentee_name', 'total comments']
mentee_comments_success
average_success_comments = mentee_comments_success['total comments'].mean()
print(average_success_comments)
# Out:
# 0.0

# %%
# total comments made by each mentor - successful
mentor_comments = project_comments[project_comments['login'].isin(success_mentor['mentor_login'])].groupby(['mentee_name']).size().fillna(0)
mentor_comments = mentor_comments.reset_index()
mentor_comments.columns = ['mentee_name', 'total mentor comments']
mentor_comments
average_mentor_comments = mentor_comments['total mentor comments'].mean()
print(average_mentor_comments)
# Out:
# 1.5

# %%
# RQ1 total comments made by each mentee - unsuccessful
mentee_comments_unsuccess = pd.merge(unsuccessful, mentee_comments, how='left', on='mentee_name').fillna(0)
mentee_comments_unsuccess.columns = ['mentee_name', 'total comments']
mentee_comments_unsuccess
avg_comments_unsuccess = mentee_comments_unsuccess['total comments'].mean()
print(avg_comments_unsuccess)
# Out:
# 0.0

# %%
# total comments made by each mentor - unsuccessful
mentor_comments2 = project_comments[project_comments['login'].isin(unsuccess_mentor['mentor_login'])].groupby(['mentee_name']).size().fillna(0)
mentor_comments2 = mentor_comments2.reset_index()
mentor_comments2.columns = ['mentee_name', 'total mentor comments']
mentor_comments2
average_mentor_comments2 = mentor_comments2['total mentor comments'].mean()
print(average_mentor_comments2)
# Out:
# 2.0

# %%
# RQ3 number of PRs that have been merged during the project time
mentee_pulls = project_pulls.groupby(['mentee_name']).size()
mentee_pulls = mentee_pulls.reset_index()
mentee_pulls.columns = ['mentee_name', 'total pulls']
mentee_pulls_success = pd.merge(success, mentee_pulls, how='left', on='mentee_name').fillna(0)
avg_pulls_success = mentee_pulls_success['total pulls'].mean()
mentee_pulls_success
print(avg_pulls_success)
# Out:
# 0.05102040816326531

# %%
# same thing but total pulls overall
mentee_pulls2 = pulls_df.groupby(['mentee_name']).size()
mentee_pulls2 = mentee_pulls2.reset_index()
mentee_pulls2.columns = ['mentee_name', 'total pulls']
mentee_pulls_success2 = pd.merge(success, mentee_pulls2, how='left', on='mentee_name').fillna(0)
avg_pulls_success2 = mentee_pulls_success2['total pulls'].mean()
mentee_pulls_success2
print(avg_pulls_success2)
# Out:
# 14.877551020408163

# %%
# RQ3 number of PRs that have been merged during the project time - unsuccessful

mentee_pulls_unsuccess = pd.merge(unsuccessful, mentee_pulls, how='left', on='mentee_name').fillna(0)
avg_pulls_unsuccess = mentee_pulls_unsuccess['total pulls'].mean()
mentee_pulls_unsuccess
print(avg_pulls_unsuccess)
# Out:
# 0.0

# %%
# same thing but total pulls overall
mentee_pulls_un2 = pulls_df.groupby(['mentee_name']).size()
mentee_pulls_un2 = mentee_pulls_un2.reset_index()
mentee_pulls_un2.columns = ['mentee_name', 'total pulls']
mentee_pulls_unsuccess2 = pd.merge(unsuccessful, mentee_pulls_un2, how='left', on='mentee_name').fillna(0)
avg_pulls_unsuccess2 = mentee_pulls_unsuccess2['total pulls'].mean()
mentee_pulls_unsuccess2
print(avg_pulls_unsuccess2)
# Out:
# 0.3888888888888889

# %%
# RQ4 pulls before a certain time - success
project_pulls_b = pulls_df[(pd.to_datetime(pulls_df['closed_at']) <= '2021-6-07')]
mentee_pulls_b = project_pulls_b.groupby(['mentee_name']).size()
mentee_pulls_b = mentee_pulls_b.reset_index()
mentee_pulls_b.columns = ['mentee_name', 'total pulls']
mentee_pulls_sb = pd.merge(success, mentee_pulls_b, how='left', on='mentee_name').fillna(0)
avg_pulls_sb = mentee_pulls_sb['total pulls'].mean()
mentee_pulls_sb
print(avg_pulls_sb)
# Out:
# 0.08163265306122448

# %%
# RQ4 pulls before a certain time - unsuccess
project_pulls_b2 = pulls_df[(pd.to_datetime(pulls_df['closed_at']) <= '2021-6-07')]
mentee_pulls_b2 = project_pulls_b2.groupby(['mentee_name']).size()
mentee_pulls_b2 = mentee_pulls_b2.reset_index()
mentee_pulls_b2.columns = ['mentee_name', 'total pulls']
mentee_pulls_sb2 = pd.merge(unsuccessful, mentee_pulls_b2, how='left', on='mentee_name').fillna(0)
avg_pulls_sb2 = mentee_pulls_sb2['total pulls'].mean()
mentee_pulls_sb2
print(avg_pulls_sb2)
# Out:
# 0.0

# %%
#RQ 4 experience
# github: time
times = user_df.loc[user_df['mentee'] == True]
times = times[['login', 'created_at']]
times = times.rename({'login': 'mentee_name'}, axis=1)
times['created_at'] = pd.to_datetime(times['created_at'])
succcess_times = pd.merge(success, times, how='left', on='mentee_name')
succcess_times = succcess_times.drop_duplicates()
avg_succcess_times = succcess_times['created_at'].mean()
avg_succcess_times
#print(avg_succcess_mtime)
# Out:
# Timestamp('2019-07-02 19:14:51.397959168+0000', tz='UTC')

# %%
#RQ 4 experience
# github: time
# unsuccessful
unsucccess_times = pd.merge(unsuccessful, times, how='left', on='mentee_name')
unsucccess_times = unsucccess_times.drop_duplicates()
avg_unsucccess_times = unsucccess_times['created_at'].mean()
avg_unsucccess_times
#print(avg_succcess_mtime)
# Out:
# Timestamp('2018-09-29 09:05:17.944444416+0000', tz='UTC')

# %%
#RQ 4 experience - mentors
# github: time
times2 = user_df.loc[user_df['mentor'] == True]
times2 = times2[['login', 'created_at']]
times2 = times2.rename({'login': 'mentor_login'}, axis=1)
times2['created_at'] = pd.to_datetime(times2['created_at'])
succcess_times2 = pd.merge(success_mentor, times2, how='left', on='mentor_login')
succcess_times2 = succcess_times2.drop_duplicates()
avg_succcess_times2 = succcess_times2['created_at'].mean()
avg_succcess_times2
#succcess_times2
# Out:
# Timestamp('2014-12-09 00:32:00.211180288+0000', tz='UTC')

# %%
#RQ 4 experience - mentors unsuccesful
# github: time
unsucccess_times2 = pd.merge(unsuccess_mentor, times2, how='left', on='mentor_login')
unsucccess_times2 = unsucccess_times2.drop_duplicates()
unsucccess_times2
avg_unsucccess_times2 = unsucccess_times2['created_at'].mean()
avg_unsucccess_times2
# Out:
# Timestamp('2015-03-16 21:27:45.437499904+0000', tz='UTC')

# %%
# RQ5 matching gender matters?
import requests

# Define a function to check the gender of a name using the Gender API
def get_gender(name):
    if name is not None:
        first_name = name.split()[0]
        response = requests.get(f'https://api.genderize.io?name={first_name}')
        json_data = response.json()
        if 'gender' in json_data:
            return json_data['gender']
        else:
            return 'Unknown'
names_df = user_df['name']
names_df = names_df.to_frame().reset_index()
names_df.columns = ['index','name']
names_df = names_df.drop('index', axis=1)
# Apply the function to the 'Name' column of the DataFrame
names_df['Gender'] = names_df['name'].apply(get_gender)

# Print the DataFrame with the gender information
names_df

# add the rows to pair mentors and mentees, and compare success
# Out:
#                      name   Gender
# 0                 SHIVAJI  Unknown
# 1                    None     None
# 2    Saúl Ibarra Corretgé  Unknown
# 3              Riken Shah  Unknown
# 4              Tim Abbott  Unknown
# ..                    ...      ...
# 315        Priyansh Rathi  Unknown
# 316             Clay John  Unknown
# 317                  None     None
# 318    Aditya Kumar Singh  Unknown
# 319        Nishtha Bodani  Unknown
#
# [320 rows x 2 columns]

# %%
# RQ2 time zones / country

# %%
# RQ4 experience
# on the project
# github
import requests
# also get the number of pulls and commits TOTAL on Github
for index, row in user_df.iterrows():
    if row['mentee']:
        login = row['login']
        owner = row['owner_name']
        repo = row['repo_name']
        # Define the username of the user you want to get the commits for
        user = 'octocat'

        # Define the date you want to get the commits before and after
        before_date = '2022-01-01T00:00:00Z'
        after_date = '2021-01-01T00:00:00Z'

# Make the API request to get the user's repositories
        url = f'https://api.github.com/users/{user}/repos'
        response = requests.get(url)

# Count the number of commits before and after the specified date for each repository
        before_count = 0
        after_count = 0
        repositories = response.json()
        for repo in repositories:
    # Make the API request to get the commits for the repository
            repo_url = repo['commits_url'][:-6]  # Remove the '{/sha}' at the end of the URL
            params = {'author': user}
            repo_response = requests.get(repo_url, params=params)
            commits = repo_response.json()

    # Count the number of commits before and after the specified date
            for commit in commits:
                commit_date = commit['commit']['author']['date']
                if commit_date < before_date:
                    before_count += 1
                elif commit_date > after_date:
                    after_count += 1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 35
#      33 # Count the number of commits before and after the specified date
#      34         for commit in commits:
# ---> 35             commit_date = commit['commit']['author']['date']
#      36             if commit_date < before_date:
#      37                 before_count += 1
#
# TypeError: string indices must be integers

# %%
# also get the number of pulls and commits that happened before the pull requests WITHIN PROJECT
# compare before, during, and after WITHIN PROJECT
import requests
me_user = {'coffeehousejazz'}
token = {'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'}
# number of commits within project
for index, row in user_df.iterrows():
    if row['mentee']:
        login = row['login']
        owner = row['owner_name']
        repo = row['repo_name']
        # Make the API request
        url = f'https://api.github.com/repos/{owner}/{repo}/commits'
        params = {'author': login}
        response = requests.get(url, auth=(me_user,token))

        # Count the number of commits before and after the specified date CHANGE
        before_date = '2022-01-01T00:00:00Z'
        after_date = '2021-01-01T00:00:00Z'
        
        before_count = 0
        after_count = 0
        commits = response.json()
        print(commits)
        for commit in commits:
            #commit_date = commit['commit']['author']['date']
            print(type(commit))
            #if commit_date < before_date:
                #before_count += 1
            #elif commit_date > after_date:
                #after_count += 1
